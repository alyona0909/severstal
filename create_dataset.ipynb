# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# данные за 2019 год
agents2019 = pd.read_csv('counterparty-analysis/agents2019.csv')
agents2019.drop("Unnamed: 0",axis=1, inplace=True)

# из 2019 года берем только таргет, так как все остальные показатели есть в файле 2020 года
agents2019 = agents2019[['Наименование ДП', 'Макс. ПДЗ за 2019 год, дней',
       'Сред. ПДЗ за 2019 год, дней',
       'Кол-во просрочек свыше 5-ти дней за 2019 год, шт.',
       'Общая сумма ПДЗ свыше 5-ти дней за 2019 год, руб.',
       'Кол-во раз ПДЗ за 2019 год, шт.']]

# %%
# данные за 2020 год
agents2020 = pd.read_csv('counterparty-analysis/agents2020.csv')

# факты не используем, будем использовать только сумму их весов (колонка Итого)
for col in agents2020.columns:
    if 'Факт' in col:
        agents2020.drop(col, axis=1, inplace=True)

# объединим таргет 2019 года (в качестве фичи) с данными за 2020 год
df20 = agents2019.merge(agents2020, how='outer', on='Наименование ДП')
# теперь таргет 19 года - фича (ПДЗ за последний год)
# в качестве фичей берем данные за последние 4 года - для 2020 года это период 2016-2019
df20.columns = [col.replace('2019', 'Y-1') for col in df20.columns]
df20.columns = [col.replace('2018', 'Y-2') for col in df20.columns]
df20.columns = [col.replace('2017', 'Y-3') for col in df20.columns]
df20.columns = [col.replace('2016', 'Y-4') for col in df20.columns]

# соберем таргет
df20['Факт просрочки'] = df20['Макс. ПДЗ за 2020 год, дней'].map(lambda x: int(x > 0))
df20['Просрочка более 30 дней'] = df20['Макс. ПДЗ за 2020 год, дней'].map(lambda x: int(x > 30))
df20['Просрочка 0-30'] = df20['Макс. ПДЗ за 2020 год, дней'].map(lambda x: int(x <= 30))

# таргет 20 больше не актуален - будет использован как фича для 21 года
df20.drop(['Макс. ПДЗ за 2020 год, дней',
       'Сред. ПДЗ за 2020 год, дней',
       'Кол-во просрочек свыше 5-ти дней за 2020 год, шт.',
       'Общая сумма ПДЗ свыше 5-ти дней за 2020 год, руб.',
       'Кол-во раз ПДЗ за 2020 год, шт.'], axis=1, inplace=True)

# %%
# данные за 2021 год
df21 = pd.read_csv('counterparty-analysis/agents2021.csv')
# те контрагенты, у которых уже дефолт - не нужны
df21 = df21[df21['Статус']=='Действующая']

# таргет 2019 года уже использован в качестве фичи за 20 год - больше не нужен
df21.drop(["Unnamed: 0", 'Макс. ПДЗ за 2019 год, дней',
       'Сред. ПДЗ за 2019 год, дней',
       'Кол-во просрочек свыше 5-ти дней за 2019 год, шт.',
       'Общая сумма ПДЗ свыше 5-ти дней за 2019 год, руб.',
       'Кол-во раз ПДЗ за 2019 год, шт.', 'Статус'], axis=1, inplace=True)

# факты не используем, будем использовать только сумму их весов (колонка Итого)
# так же не нужны данные за 2016 год, так как для 2021 года используем 2017-2020 года
for col in df21.columns:
    if 'Факт' in col or '2016' in col:
        df21.drop(col, axis=1, inplace=True)

# теперь таргет 20 года - фича (ПДЗ за последний год)
# в качестве фичей берем данные за последние 4 года - для 2021 года это период 2017-2020
df21.columns = [col.replace('2020', 'Y-1') for col in df21.columns]
df21.columns = [col.replace('2019', 'Y-2') for col in df21.columns]
df21.columns = [col.replace('2018', 'Y-3') for col in df21.columns]
df21.columns = [col.replace('2017', 'Y-4') for col in df21.columns]

# соберем таргет
df21['Факт просрочки'] = (df21['ПДЗ 1-30'] + df21['ПДЗ 31-90'] +
                          df21['ПДЗ 91-365'] + df21['ПДЗ более 365']).apply(lambda x: int(x >= 1))
df21['Просрочка более 30 дней'] = (df21['ПДЗ 31-90'] + df21['ПДЗ 91-365'] + 
                                   df21['ПДЗ более 365']).apply(lambda x: int(x >= 1))
df21['Просрочка 0-30'] = df21['ПДЗ 1-30']

# предыдущий таргет 21 больше не актуален
df21.drop(['ПДЗ 1-30', 'ПДЗ 31-90', 'ПДЗ 91-365', 'ПДЗ более 365'], axis=1, inplace=True)

# %%
# для 20 года нет отчетности по оценке потенциала контрагента - заполним их -1
df20['Оценка потенциала контрагента 1, руб.'] = -1
df20['Оценка потенциала контрагента 2, руб.'] = -1

# %%
# объединим в один датасет
df = pd.concat([df20, df21]).reset_index(drop=True)
df.drop('Наименование ДП', axis=1, inplace=True)
df
# Out:
#      Макс. ПДЗ за Y-1 год, дней  Сред. ПДЗ за Y-1 год, дней  \
# 0                             0                        0.00
# 1                             0                        0.00
# 2                             7                        5.50
# 3                             0                        0.00
# 4                             2                        2.00
# ..                          ...                         ...
# 848                           4                        1.75
# 849                           0                        0.00
# 850                           0                        0.00
# 851                           0                        0.00
# 852                           0                        0.00
#
#      Кол-во просрочек свыше 5-ти дней за Y-1 год, шт.  \
# 0                                                   0
# 1                                                   0
# 2                                                   1
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 848                                                 0
# 849                                                 0
# 850                                                 0
# 851                                                 0
# 852                                                 0
#
#      Общая сумма ПДЗ свыше 5-ти дней за Y-1 год, руб.  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                       132825.299363
# 3                                            0.000000
# 4                                            0.000000
# ..                                                ...
# 848                                          0.000000
# 849                                          0.000000
# 850                                          0.000000
# 851                                          0.000000
# 852                                          0.000000
#
#      Кол-во раз ПДЗ за Y-1 год, шт.  Итого  Y-4, Нематериальные активы, RUB  \
# 0                                 0   10.0                     2.895541e+06
# 1                                 0   20.0                     0.000000e+00
# 2                                 2   40.0                     2.468153e+06
# 3                                 0   10.0                     0.000000e+00
# 4                                 2   20.0                     5.503185e+05
# ..                              ...    ...                              ...
# 848                               4   10.0                     0.000000e+00
# 849                               0    5.0                     0.000000e+00
# 850                               0   65.0                     0.000000e+00
# 851                               0    5.0                     3.375796e+04
# 852                               0   20.0                     0.000000e+00
#
#      Y-3, Нематериальные активы, RUB  Y-2, Нематериальные активы, RUB  \
# 0                       6.245860e+06                     9.050955e+06
# 1                       3.885350e+04                     3.439490e+04
# 2                       1.288025e+07                     8.694904e+06
# 3                       0.000000e+00                     0.000000e+00
# 4                       5.210191e+05                     4.490446e+05
# ..                               ...                              ...
# 848                     0.000000e+00                     0.000000e+00
# 849                     0.000000e+00                     0.000000e+00
# 850                     0.000000e+00                     0.000000e+00
# 851                     1.847134e+04                     8.917197e+03
# 852                     0.000000e+00                     0.000000e+00
#
#      Y-1, Нематериальные активы, RUB  ...  \
# 0                       9.885987e+06  ...
# 1                       2.929936e+04  ...
# 2                       4.958599e+06  ...
# 3                       0.000000e+00  ...
# 4                       3.987261e+05  ...
# ..                               ...  ...
# 848                     0.000000e+00  ...
# 849                     0.000000e+00  ...
# 850                     0.000000e+00  ...
# 851                     6.369427e+03  ...
# 852                     8.802548e+05  ...
#
#      Y-1, Прибыль (убыток) до налогообложения , RUB  \
# 0                                      3.603784e+09
# 1                                      8.747516e+07
# 2                                     -6.456439e+08
# 3                                      3.999298e+09
# 4                                      4.960408e+10
# ..                                              ...
# 848                                    4.008280e+06
# 849                                    0.000000e+00
# 850                                    4.284076e+06
# 851                                    2.835159e+07
# 852                                   -9.388369e+08
#
#      Y-4, Прибыль (убыток) от продажи, RUB  \
# 0                             3.280355e+09
# 1                             1.630064e+07
# 2                             4.148586e+08
# 3                             4.903117e+09
# 4                             2.338912e+10
# ..                                     ...
# 848                           0.000000e+00
# 849                           0.000000e+00
# 850                           0.000000e+00
# 851                           1.465019e+08
# 852                           0.000000e+00
#
#      Y-3, Прибыль (убыток) от продажи, RUB  \
# 0                             6.200120e+09
# 1                             1.109172e+07
# 2                             1.611318e+08
# 3                             5.186553e+09
# 4                             3.727984e+10
# ..                                     ...
# 848                           0.000000e+00
# 849                           0.000000e+00
# 850                           0.000000e+00
# 851                           6.499554e+07
# 852                           0.000000e+00
#
#      Y-2, Прибыль (убыток) от продажи, RUB  \
# 0                             8.716191e+08
# 1                             5.135732e+07
# 2                            -9.298981e+07
# 3                             7.869977e+09
# 4                             5.307524e+10
# ..                                     ...
# 848                           4.192994e+06
# 849                           0.000000e+00
# 850                           4.573248e+05
# 851                           7.620446e+07
# 852                           0.000000e+00
#
#      Y-1, Прибыль (убыток) от продажи, RUB  Факт просрочки  \
# 0                             3.658634e+09               1
# 1                             9.411019e+07               1
# 2                            -1.207210e+08               1
# 3                             4.029232e+09               1
# 4                             5.622122e+10               1
# ..                                     ...             ...
# 848                           6.487898e+06               1
# 849                           0.000000e+00               0
# 850                           8.932484e+06               1
# 851                           2.644204e+07               0
# 852                          -7.485197e+08               0
#
#      Просрочка более 30 дней  Просрочка 0-30  \
# 0                          0               1
# 1                          0               1
# 2                          0               1
# 3                          0               1
# 4                          0               1
# ..                       ...             ...
# 848                        0               1
# 849                        0               0
# 850                        0               1
# 851                        0               0
# 852                        0               0
#
#      Оценка потенциала контрагента 1, руб.  \
# 0                            -1.000000e+00
# 1                            -1.000000e+00
# 2                            -1.000000e+00
# 3                            -1.000000e+00
# 4                            -1.000000e+00
# ..                                     ...
# 848                           5.095541e+06
# 849                           0.000000e+00
# 850                           3.184713e+06
# 851                           5.095541e+06
# 852                           0.000000e+00
#
#      Оценка потенциала контрагента 2, руб.
# 0                            -1.000000e+00
# 1                            -1.000000e+00
# 2                            -1.000000e+00
# 3                            -1.000000e+00
# 4                            -1.000000e+00
# ..                                     ...
# 848                           5.095541e+06
# 849                           2.624204e+05
# 850                           3.184713e+06
# 851                           5.095541e+06
# 852                           0.000000e+00
#
# [853 rows x 75 columns]

# %%
# заполним пустые значения -1, так как это означает что ни один из факторов не сработал
df['Итого'] = df['Итого'].fillna(-1)

# %%
df
# Out:
#      Макс. ПДЗ за Y-1 год, дней  Сред. ПДЗ за Y-1 год, дней  \
# 0                             0                        0.00
# 1                             0                        0.00
# 2                             7                        5.50
# 3                             0                        0.00
# 4                             2                        2.00
# ..                          ...                         ...
# 848                           4                        1.75
# 849                           0                        0.00
# 850                           0                        0.00
# 851                           0                        0.00
# 852                           0                        0.00
#
#      Кол-во просрочек свыше 5-ти дней за Y-1 год, шт.  \
# 0                                                   0
# 1                                                   0
# 2                                                   1
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 848                                                 0
# 849                                                 0
# 850                                                 0
# 851                                                 0
# 852                                                 0
#
#      Общая сумма ПДЗ свыше 5-ти дней за Y-1 год, руб.  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                       132825.299363
# 3                                            0.000000
# 4                                            0.000000
# ..                                                ...
# 848                                          0.000000
# 849                                          0.000000
# 850                                          0.000000
# 851                                          0.000000
# 852                                          0.000000
#
#      Кол-во раз ПДЗ за Y-1 год, шт.  Итого  Y-4, Нематериальные активы, RUB  \
# 0                                 0   10.0                     2.895541e+06
# 1                                 0   20.0                     0.000000e+00
# 2                                 2   40.0                     2.468153e+06
# 3                                 0   10.0                     0.000000e+00
# 4                                 2   20.0                     5.503185e+05
# ..                              ...    ...                              ...
# 848                               4   10.0                     0.000000e+00
# 849                               0    5.0                     0.000000e+00
# 850                               0   65.0                     0.000000e+00
# 851                               0    5.0                     3.375796e+04
# 852                               0   20.0                     0.000000e+00
#
#      Y-3, Нематериальные активы, RUB  Y-2, Нематериальные активы, RUB  \
# 0                       6.245860e+06                     9.050955e+06
# 1                       3.885350e+04                     3.439490e+04
# 2                       1.288025e+07                     8.694904e+06
# 3                       0.000000e+00                     0.000000e+00
# 4                       5.210191e+05                     4.490446e+05
# ..                               ...                              ...
# 848                     0.000000e+00                     0.000000e+00
# 849                     0.000000e+00                     0.000000e+00
# 850                     0.000000e+00                     0.000000e+00
# 851                     1.847134e+04                     8.917197e+03
# 852                     0.000000e+00                     0.000000e+00
#
#      Y-1, Нематериальные активы, RUB  ...  \
# 0                       9.885987e+06  ...
# 1                       2.929936e+04  ...
# 2                       4.958599e+06  ...
# 3                       0.000000e+00  ...
# 4                       3.987261e+05  ...
# ..                               ...  ...
# 848                     0.000000e+00  ...
# 849                     0.000000e+00  ...
# 850                     0.000000e+00  ...
# 851                     6.369427e+03  ...
# 852                     8.802548e+05  ...
#
#      Y-1, Прибыль (убыток) до налогообложения , RUB  \
# 0                                      3.603784e+09
# 1                                      8.747516e+07
# 2                                     -6.456439e+08
# 3                                      3.999298e+09
# 4                                      4.960408e+10
# ..                                              ...
# 848                                    4.008280e+06
# 849                                    0.000000e+00
# 850                                    4.284076e+06
# 851                                    2.835159e+07
# 852                                   -9.388369e+08
#
#      Y-4, Прибыль (убыток) от продажи, RUB  \
# 0                             3.280355e+09
# 1                             1.630064e+07
# 2                             4.148586e+08
# 3                             4.903117e+09
# 4                             2.338912e+10
# ..                                     ...
# 848                           0.000000e+00
# 849                           0.000000e+00
# 850                           0.000000e+00
# 851                           1.465019e+08
# 852                           0.000000e+00
#
#      Y-3, Прибыль (убыток) от продажи, RUB  \
# 0                             6.200120e+09
# 1                             1.109172e+07
# 2                             1.611318e+08
# 3                             5.186553e+09
# 4                             3.727984e+10
# ..                                     ...
# 848                           0.000000e+00
# 849                           0.000000e+00
# 850                           0.000000e+00
# 851                           6.499554e+07
# 852                           0.000000e+00
#
#      Y-2, Прибыль (убыток) от продажи, RUB  \
# 0                             8.716191e+08
# 1                             5.135732e+07
# 2                            -9.298981e+07
# 3                             7.869977e+09
# 4                             5.307524e+10
# ..                                     ...
# 848                           4.192994e+06
# 849                           0.000000e+00
# 850                           4.573248e+05
# 851                           7.620446e+07
# 852                           0.000000e+00
#
#      Y-1, Прибыль (убыток) от продажи, RUB  Факт просрочки  \
# 0                             3.658634e+09               1
# 1                             9.411019e+07               1
# 2                            -1.207210e+08               1
# 3                             4.029232e+09               1
# 4                             5.622122e+10               1
# ..                                     ...             ...
# 848                           6.487898e+06               1
# 849                           0.000000e+00               0
# 850                           8.932484e+06               1
# 851                           2.644204e+07               0
# 852                          -7.485197e+08               0
#
#      Просрочка более 30 дней  Просрочка 0-30  \
# 0                          0               1
# 1                          0               1
# 2                          0               1
# 3                          0               1
# 4                          0               1
# ..                       ...             ...
# 848                        0               1
# 849                        0               0
# 850                        0               1
# 851                        0               0
# 852                        0               0
#
#      Оценка потенциала контрагента 1, руб.  \
# 0                            -1.000000e+00
# 1                            -1.000000e+00
# 2                            -1.000000e+00
# 3                            -1.000000e+00
# 4                            -1.000000e+00
# ..                                     ...
# 848                           5.095541e+06
# 849                           0.000000e+00
# 850                           3.184713e+06
# 851                           5.095541e+06
# 852                           0.000000e+00
#
#      Оценка потенциала контрагента 2, руб.
# 0                            -1.000000e+00
# 1                            -1.000000e+00
# 2                            -1.000000e+00
# 3                            -1.000000e+00
# 4                            -1.000000e+00
# ..                                     ...
# 848                           5.095541e+06
# 849                           2.624204e+05
# 850                           3.184713e+06
# 851                           5.095541e+06
# 852                           0.000000e+00
#
# [853 rows x 75 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 75 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Макс. ПДЗ за Y-1 год, дней                        853 non-null    int64
#  1   Сред. ПДЗ за Y-1 год, дней                        853 non-null    float64
#  2   Кол-во просрочек свыше 5-ти дней за Y-1 год, шт.  853 non-null    int64
#  3   Общая сумма ПДЗ свыше 5-ти дней за Y-1 год, руб.  853 non-null    float64
#  4   Кол-во раз ПДЗ за Y-1 год, шт.                    853 non-null    int64
#  5   Итого                                             853 non-null    float64
#  6   Y-4, Нематериальные активы, RUB                   853 non-null    float64
#  7   Y-3, Нематериальные активы, RUB                   853 non-null    float64
#  8   Y-2, Нематериальные активы, RUB                   853 non-null    float64
#  9   Y-1, Нематериальные активы, RUB                   853 non-null    float64
#  10  Y-4, Основные средства , RUB                      853 non-null    float64
#  11  Y-3, Основные средства , RUB                      853 non-null    float64
#  12  Y-2, Основные средства , RUB                      853 non-null    float64
#  13  Y-1, Основные средства , RUB                      853 non-null    float64
#  14  Y-4, Внеоборотные активы, RUB                     853 non-null    float64
#  15  Y-3, Внеоборотные активы, RUB                     853 non-null    float64
#  16  Y-2, Внеоборотные активы, RUB                     853 non-null    float64
#  17  Y-1, Внеоборотные активы, RUB                     853 non-null    float64
#  18  Y-4, Дебиторская задолженность, RUB               853 non-null    float64
#  19  Y-3, Дебиторская задолженность, RUB               853 non-null    float64
#  20  Y-2, Дебиторская задолженность, RUB               853 non-null    float64
#  21  Y-1, Дебиторская задолженность, RUB               853 non-null    float64
#  22  Y-4, Оборотные активы, RUB                        853 non-null    float64
#  23  Y-3, Оборотные активы, RUB                        853 non-null    float64
#  24  Y-2, Оборотные активы, RUB                        853 non-null    float64
#  25  Y-1, Оборотные активы, RUB                        853 non-null    float64
#  26  Y-4, Уставный капитал , RUB                       853 non-null    float64
#  27  Y-3, Уставный капитал , RUB                       853 non-null    float64
#  28  Y-2, Уставный капитал , RUB                       853 non-null    float64
#  29  Y-1, Уставный капитал , RUB                       853 non-null    float64
#  30  Y-4, Капитал и резервы, RUB                       853 non-null    float64
#  31  Y-3, Капитал и резервы, RUB                       853 non-null    float64
#  32  Y-2, Капитал и резервы, RUB                       853 non-null    float64
#  33  Y-1, Капитал и резервы, RUB                       853 non-null    float64
#  34  Y-4, Заёмные средства (долгосрочные), RUB         853 non-null    float64
#  35  Y-3, Заёмные средства (долгосрочные), RUB         853 non-null    float64
#  36  Y-2, Заёмные средства (долгосрочные), RUB         853 non-null    float64
#  37  Y-1, Заёмные средства (долгосрочные), RUB         853 non-null    float64
#  38  Y-4, Долгосрочные обязательства, RUB              853 non-null    float64
#  39  Y-3, Долгосрочные обязательства, RUB              853 non-null    float64
#  40  Y-2, Долгосрочные обязательства, RUB              853 non-null    float64
#  41  Y-1, Долгосрочные обязательства, RUB              853 non-null    float64
#  42  Y-4, Заёмные средства (краткосрочные), RUB        853 non-null    float64
#  43  Y-3, Заёмные средства (краткосрочные), RUB        853 non-null    float64
#  44  Y-2, Заёмные средства (краткосрочные), RUB        853 non-null    float64
#  45  Y-1, Заёмные средства (краткосрочные), RUB        853 non-null    float64
#  46  Y-4, Кредиторская задолженность, RUB              853 non-null    float64
#  47  Y-3, Кредиторская задолженность, RUB              853 non-null    float64
#  48  Y-2, Кредиторская задолженность, RUB              853 non-null    float64
#  49  Y-1, Кредиторская задолженность, RUB              853 non-null    float64
#  50  Y-4, Краткосрочные обязательства, RUB             853 non-null    float64
#  51  Y-3, Краткосрочные обязательства, RUB             853 non-null    float64
#  52  Y-2, Краткосрочные обязательства, RUB             853 non-null    float64
#  53  Y-1, Краткосрочные обязательства, RUB             853 non-null    float64
#  54  Y-4, Выручка, RUB                                 853 non-null    float64
#  55  Y-3, Выручка, RUB                                 853 non-null    float64
#  56  Y-2, Выручка, RUB                                 853 non-null    float64
#  57  Y-1, Выручка, RUB                                 853 non-null    float64
#  58  Y-4, Себестоимость продаж, RUB                    853 non-null    float64
#  59  Y-3, Себестоимость продаж, RUB                    853 non-null    float64
#  60  Y-2, Себестоимость продаж, RUB                    853 non-null    float64
#  61  Y-1, Себестоимость продаж, RUB                    853 non-null    float64
#  62  Y-4, Прибыль (убыток) до налогообложения , RUB    853 non-null    float64
#  63  Y-3, Прибыль (убыток) до налогообложения , RUB    853 non-null    float64
#  64  Y-2, Прибыль (убыток) до налогообложения , RUB    853 non-null    float64
#  65  Y-1, Прибыль (убыток) до налогообложения , RUB    853 non-null    float64
#  66  Y-4, Прибыль (убыток) от продажи, RUB             853 non-null    float64
#  67  Y-3, Прибыль (убыток) от продажи, RUB             853 non-null    float64
#  68  Y-2, Прибыль (убыток) от продажи, RUB             853 non-null    float64
#  69  Y-1, Прибыль (убыток) от продажи, RUB             853 non-null    float64
#  70  Факт просрочки                                    853 non-null    int64
#  71  Просрочка более 30 дней                           853 non-null    int64
#  72  Просрочка 0-30                                    853 non-null    int64
#  73  Оценка потенциала контрагента 1, руб.             853 non-null    float64
#  74  Оценка потенциала контрагента 2, руб.             853 non-null    float64
# dtypes: float64(69), int64(6)
# memory usage: 499.9 KB

# %%
df.to_csv('data.csv', index=False)
